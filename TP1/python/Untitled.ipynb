# %%
import BayesNetwork as bn
import FactorGraph as fg

bnet = bn.Network()
C = bnet.addNode("C", 0.001)
T = bnet.addNode("T", 0.002)
A = bnet.addNode("A", [0.95,0.94,0.29,0.001], parents=[T,C])
M = bnet.addNode("M", [0.90,0.05], parents=A)
J = bnet.addNode("J", [0.70,0.01], parents=A)

bnet.drawGraph()

# %%
bnet.drawDistribution()

# %%
fgraph = fg.graphFromBayesNet(bnet)
fgraph.drawGraph()

# %%
fgraph.mostProbableConfiguration(A==True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bf0338f808c6> in <module>()
# ----> 1 fgraph.mostProbableConfiguration(A==True)
#
# /home/gaby/Ecole/EPM/INF8225/TP1/python/probatoolbox.py in __eq__(self, other)
#      84         if isinstance(other, RandomVariable):
#      85             return self.subset is other.subset and self.values == other.values and self.name == other.name
# ---> 86         return Event.varEq(self, other)
#      87
#      88     def __ne__(self, other):
#
# TypeError: unbound method varEq() must be called with Event instance as first argument (got RandomVariable instance instead)
